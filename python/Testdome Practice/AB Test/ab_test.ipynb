# %% [markdown]
# ![alt text](image.png)

# %%
import pandas as pd
import numpy as np
pA = 0.6
pB = 0.4
pSA = 0.08§
pSB = 0.04
def total_prob(p_events, p_probs):
    return (p_events.T @ p_probs).flatten()[0]
def bayes(pA, pB, pBA):
    return pBA * pA / pB
            # pA    pB
prior_prob = np.array(np.c_[[0.6, 0.4]])
prob_event = np.array(np.c_[[0.08, 0.04]])
print(f"P(A): {pA}")
print(f"P(B): {pB}")
print(f"P(S|A): {pSA}")
print(f"P(S|B): {pSB}")
pS = total_prob(prob_event, prior_prob)
print(f"Total Probability: {pS}")
print(f"P(A|S): {bayes(pA, pS, pSA)}")
print(f"P(B|S): {bayes(pB, pS, pSB)}")
# Out:
# P(A): 0.6
# P(B): 0.4
# P(S|A): 0.08
# P(S|B): 0.04
# Total Probability: 0.064
# P(A|S): 0.75
# P(B|S): 0.25
