# %% [markdown]
# ![alt text](image.png)

# %%
import numpy as np
import scipy as sc

from sympy import symbols
from sympy import solve
pA,pB,pS, pAS, pSA, pBS, pBA = symbols('pA pB pS pAS pSA pBS pBA')


pA =0.6
pB = 




# def bayes(pA, pB, pBA):
#     return (pBA * pA) / pB

#p(ANB) = p(BNA) = 0

#p(A|B) =  0
#p(B|A) = 0
#



# p_A_S = (p_S_A * p_S) / p_A
# print(p_A_S)

# p_B_S = (p_S_B * p_S) / p_B
# print(p_B_S)

# p_S = (p_B_S * p_B) / p_S_B 
# p_S = (p_A_S * p_A) / p_S_A

# (p_A_S * p_A) / p_S_A = (p_B_S * p_B) / p_S_B

# #p_A_S / p_B_S = k = p_S_A * p_B / p_S_B * p_A
# k = p_S_A * p_B / p_S_B * p_A
# print(k)
# #p_A_S = k * p_B_S = (p_S_A * p_S) / p_A

# #k * p_A * p_B_S / p_S_A = p_B *p_B_S / p_S_B = p_S
# #k * p_A * (p_S_B ) / p_S_A*p_B = p_S/p_S
# ans = k * p_A * (p_S_B ) / p_S_A*p_B 
# print(ans)
# Out:
# 0.48
# 0.0576
